# %% [markdown]
# <a href="https://colab.research.google.com/github/NAU-CS077-012026/lab-03022026-Chien2326/blob/main/lab_03022026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PYSPARK ESSENTIALS - PHÂN TÍCH DỮ LIỆU BÁN LẺ**
#
# **Mục tiêu**: Sinh viên hiểu và vận dụng được các nhóm hàm cốt lõi của Spark: Inspection, Transformation, Aggregation và I/O. Bối cảnh: Bạn là Data Engineer cho chuỗi siêu thị "TechMart". Bạn cần xử lý dữ liệu giao dịch để báo cáo doanh thu

# %% [markdown]
# ##**PHẦN 0: CHUẨN BỊ MÔI TRƯỜNG & DỮ LIỆU**
# Chạy cell này để cài đặt Spark và tạo dữ liệu giả lập (Mock Data)

# %%
# 1. Cài đặt PySpark (Chạy trên Google Colab)
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install -q pyspark

# 2. Khởi tạo Spark Session
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
import random

spark = SparkSession.builder.appName("Lab_PySpark_Functions").getOrCreate()


# 3. Tạo dữ liệu giả lập (DataFrame)
data = []
cities = ["Hanoi", "HCM", "Danang", "Cantho"]
products = ["Laptop", "Mouse", "Keyboard", "Headphone", "Monitor"]
categories = ["Computer", "Accessory", "Accessory", "Audio", "Display"]

for i in range(1, 101): # Tạo 100 dòng
    prod_idx = random.randint(0, 4)
    row = (
        f"TRX_{i:03d}",                 # TransactionID
        products[prod_idx],             # Product
        categories[prod_idx],           # Category
        random.randint(10, 50) * 10,    # Price ($100 - $500)
        random.randint(1, 5),           # Quantity
        random.choice(cities)           # City
    )
    data.append(row)

columns = ["TransactionID", "Product", "Category", "Price", "Quantity", "City"]
df = spark.createDataFrame(data, columns)

print("✅ Đã tạo xong dữ liệu mẫu!")
# Out:
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jre-headless_8u472-ga-1%7e22.04_amd64.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jdk-headless_8u472-ga-1%7e22.04_amd64.deb  404  Not Found [IP: 91.189.91.83 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# ✅ Đã tạo xong dữ liệu mẫu!

# %% [markdown]
# ##**PHẦN 1: KHÁM PHÁ DỮ LIỆU (INSPECTION)**
#
# **Các hàm**: show(), printSchema(), select(), describe()
# ###**1. Ví dụ minh họa**
# Để hiểu dữ liệu đang có gì, chúng ta cần xem cấu trúc và một vài dòng mẫu.

# %%
# Xem cấu trúc dữ liệu (Tên cột, kiểu dữ liệu)
print("--- Schema ---")
df.printSchema()

# Xem 5 dòng đầu tiên
print("--- 5 Dòng đầu ---")
df.show(5)

# Thống kê mô tả (Count, Mean, Min, Max) cột Giá
print("--- Thống kê giá ---")
df.describe("Price").show()
# Out:
# --- Schema ---
# root
#  |-- TransactionID: string (nullable = true)
#  |-- Product: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Price: long (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- City: string (nullable = true)
#
# --- 5 Dòng đầu ---
# +-------------+---------+---------+-----+--------+------+
# |TransactionID|  Product| Category|Price|Quantity|  City|
# +-------------+---------+---------+-----+--------+------+
# |      TRX_001|    Mouse|Accessory|  350|       3|Danang|
# |      TRX_002|  Monitor|  Display|  170|       3|Danang|
# |      TRX_003|   Laptop| Computer|  130|       5| Hanoi|
# |      TRX_004|Headphone|    Audio|  220|       1| Hanoi|
# |      TRX_005| Keyboard|Accessory|  430|       5|   HCM|
# +-------------+---------+---------+-----+--------+------+
# only showing top 5 rows
# --- Thống kê giá ---
# +-------+-----------------+
# |summary|            Price|
# +-------+-----------------+
# |  count|              100|
# |   mean|            303.4|
# | stddev|114.3909652432959|
# |    min|              110|
# |    max|              490|
# +-------+-----------------+

# %% [markdown]
# ###**Bài tập 1 (Sinh viên code tại đây)**
# **Yêu cầu:** Hãy dùng hàm select() để chỉ hiển thị 2 cột là Product và City, và chỉ hiện 10 dòng đầu tiên.

# %%
# CODE CỦA BẠN Ở ĐÂY:
# Goi y: df.select(..., ...).show(...)
df.select(df.Product, df.City).show(10)
# Out:
# +---------+------+
# |  Product|  City|
# +---------+------+
# |    Mouse|Danang|
# |  Monitor|Danang|
# |   Laptop| Hanoi|
# |Headphone| Hanoi|
# | Keyboard|   HCM|
# |   Laptop| Hanoi|
# |  Monitor|   HCM|
# |Headphone|Cantho|
# |  Monitor|   HCM|
# | Keyboard|Cantho|
# +---------+------+
# only showing top 10 rows

# %% [markdown]
# ##**PHẦN 2: LỌC DỮ LIỆU (FILTERING)**
#
# **Các hàm:** filter() (hoặc where), toán tử & (AND), | (OR).
#
# ###**2. Ví dụ minh họa**
# Yêu cầu tìm các đơn hàng bán tại "Hanoi" có giá trị sản phẩm trên $300.

# %%
# Lọc theo 2 điều kiện kết hợp
# Lưu ý: Mỗi điều kiện phải để trong ngoặc đơn ()
high_value_hanoi = df.filter((col("City") == "Hanoi") & (col("Price") > 300))

high_value_hanoi.show()
# Out:
# +-------------+---------+---------+-----+--------+-----+
# |TransactionID|  Product| Category|Price|Quantity| City|
# +-------------+---------+---------+-----+--------+-----+
# |      TRX_006|   Laptop| Computer|  450|       3|Hanoi|
# |      TRX_019|    Mouse|Accessory|  400|       2|Hanoi|
# |      TRX_024| Keyboard|Accessory|  350|       3|Hanoi|
# |      TRX_038|  Monitor|  Display|  360|       2|Hanoi|
# |      TRX_040|  Monitor|  Display|  460|       2|Hanoi|
# |      TRX_045|Headphone|    Audio|  370|       5|Hanoi|
# |      TRX_066|Headphone|    Audio|  350|       4|Hanoi|
# |      TRX_076|  Monitor|  Display|  380|       2|Hanoi|
# |      TRX_085|Headphone|    Audio|  330|       2|Hanoi|
# +-------------+---------+---------+-----+--------+-----+

# %% [markdown]
# ###**Bài tập 2 (Sinh viên code tại đây)**
#
# **Yêu cầu:** Hãy lọc ra các đơn hàng thuộc danh mục (Category) là "Accessory" HOẶC đơn hàng có số lượng (Quantity) lớn hơn 3.

# %%
# CODE CỦA BẠN Ở ĐÂY:
baitap2 = df.filter((col("Category") == "Accessory") | (col("Quantity") > 3))
baitap2.show()
# Out:
# +-------------+--------+---------+-----+--------+------+
# |TransactionID| Product| Category|Price|Quantity|  City|
# +-------------+--------+---------+-----+--------+------+
# |      TRX_001|   Mouse|Accessory|  350|       3|Danang|
# |      TRX_003|  Laptop| Computer|  130|       5| Hanoi|
# |      TRX_005|Keyboard|Accessory|  430|       5|   HCM|
# |      TRX_010|Keyboard|Accessory|  470|       4|Cantho|
# |      TRX_013|Keyboard|Accessory|  290|       2|Cantho|
# |      TRX_015|  Laptop| Computer|  190|       5|   HCM|
# |      TRX_016|  Laptop| Computer|  320|       4|Danang|
# |      TRX_017|Keyboard|Accessory|  390|       3|Danang|
# |      TRX_019|   Mouse|Accessory|  400|       2| Hanoi|
# |      TRX_020|   Mouse|Accessory|  230|       1|Danang|
# |      TRX_021|   Mouse|Accessory|  140|       5|Cantho|
# |      TRX_022|   Mouse|Accessory|  450|       5|Cantho|
# |      TRX_023|   Mouse|Accessory|  350|       1|Danang|
# |      TRX_024|Keyboard|Accessory|  350|       3| Hanoi|
# |      TRX_025|   Mouse|Accessory|  450|       4|   HCM|
# |      TRX_026|   Mouse|Accessory|  240|       1|Danang|
# |      TRX_027|   Mouse|Accessory|  320|       5|Cantho|
# |      TRX_028|Keyboard|Accessory|  130|       5|Cantho|
# |      TRX_030|   Mouse|Accessory|  280|       2|Cantho|
# |      TRX_031|Keyboard|Accessory|  220|       2| Hanoi|
# +-------------+--------+---------+-----+--------+------+
# only showing top 20 rows

# %% [markdown]
# ##**PHẦN 3: BIẾN ĐỔI CỘT (TRANSFORMATION)**
# **Các hàm:** withColumn() (Thêm/Sửa cột), drop() (Xóa cột)
# ###**3. Ví dụ minh họa**
# Chúng ta cần tính tổng tiền cho mỗi đơn hàng. Công thức: Total = Price * Quantity.

# %%
# Tạo cột mới tên là "TotalValue"
df_processed = df.withColumn("TotalValue", col("Price") * col("Quantity"))

df_processed.show(5)
# Out:
# +-------------+---------+---------+-----+--------+------+----------+
# |TransactionID|  Product| Category|Price|Quantity|  City|TotalValue|
# +-------------+---------+---------+-----+--------+------+----------+
# |      TRX_001|  Monitor|  Display|  230|       1|Danang|       230|
# |      TRX_002|   Laptop| Computer|  190|       3|Danang|       570|
# |      TRX_003|    Mouse|Accessory|  100|       3|Danang|       300|
# |      TRX_004|Headphone|    Audio|  250|       3|Cantho|       750|
# |      TRX_005|   Laptop| Computer|  460|       1|   HCM|       460|
# +-------------+---------+---------+-----+--------+------+----------+
# only showing top 5 rows

# %% [markdown]
# ###**Bài tập 3 (Sinh viên code tại đây)**
# **Yêu cầu**: Nhân dịp khuyến mãi, hãy tạo thêm một cột mới tên là DiscountedPrice. Giá trị cột này bằng 90% giá gốc (Price * 0.9).

# %%
# CODE CỦA BẠN Ở ĐÂY:
df_cotMoi = df.withColumn("DiscountedPrice", col("Price")*0.9)
df_cotMoi.show()
# Out:
# +-------------+---------+---------+-----+--------+------+---------------+
# |TransactionID|  Product| Category|Price|Quantity|  City|DiscountedPrice|
# +-------------+---------+---------+-----+--------+------+---------------+
# |      TRX_001|    Mouse|Accessory|  350|       3|Danang|          315.0|
# |      TRX_002|  Monitor|  Display|  170|       3|Danang|          153.0|
# |      TRX_003|   Laptop| Computer|  130|       5| Hanoi|          117.0|
# |      TRX_004|Headphone|    Audio|  220|       1| Hanoi|          198.0|
# |      TRX_005| Keyboard|Accessory|  430|       5|   HCM|          387.0|
# |      TRX_006|   Laptop| Computer|  450|       3| Hanoi|          405.0|
# |      TRX_007|  Monitor|  Display|  150|       1|   HCM|          135.0|
# |      TRX_008|Headphone|    Audio|  420|       3|Cantho|          378.0|
# |      TRX_009|  Monitor|  Display|  140|       1|   HCM|          126.0|
# |      TRX_010| Keyboard|Accessory|  470|       4|Cantho|          423.0|
# |      TRX_011|Headphone|    Audio|  420|       2|Danang|          378.0|
# |      TRX_012|Headphone|    Audio|  310|       2|Cantho|          279.0|
# |      TRX_013| Keyboard|Accessory|  290|       2|Cantho|          261.0|
# |      TRX_014|Headphone|    Audio|  260|       3|Danang|          234.0|
# |      TRX_015|   Laptop| Computer|  190|       5|   HCM|          171.0|
# |      TRX_016|   Laptop| Computer|  320|       4|Danang|          288.0|
# |      TRX_017| Keyboard|Accessory|  390|       3|Danang|          351.0|
# |      TRX_018|  Monitor|  Display|  420|       2|   HCM|          378.0|
# |      TRX_019|    Mouse|Accessory|  400|       2| Hanoi|          360.0|
# |      TRX_020|    Mouse|Accessory|  230|       1|Danang|          207.0|
# +-------------+---------+---------+-----+--------+------+---------------+
# only showing top 20 rows

# %% [markdown]
# ##**PHẦN 4: TỔNG HỢP & THỐNG KÊ (AGGREGATION) - QUAN TRỌNG**
# **Các hàm**: groupBy(), agg(), sum(), count(), avg(), max().
#
# ###**4. Ví dụ minh họa**
# Tính tổng doanh thu theo từng Thành phố để xem nơi nào bán tốt nhất.

# %%
# Bước 1: Phải có cột TotalValue trước (lấy từ phần trước)
df_cal = df.withColumn("TotalValue", col("Price") * col("Quantity"))

# Bước 2: GroupBy và Sum
report_city = df_cal.groupBy("City") \
                  .agg(sum("TotalValue").alias("Revenue")) \
                  .orderBy(col("Revenue").desc()) # Sắp xếp giảm dần

report_city.show()
# Out:
# +------+-------+
# |  City|Revenue|
# +------+-------+
# |Cantho|  30910|
# |   HCM|  25520|
# |Danang|  20970|
# | Hanoi|  13270|
# +------+-------+

# %% [markdown]
# ###**Bài tập 4 (Sinh viên code tại đây)**
# **Yêu cầu**: Hãy tính Tổng số lượng sản phẩm (Quantity) đã bán được theo từng Danh mục (Category).

# %%
# CODE CỦA BẠN Ở ĐÂY:
# Goi y: groupBy("Category").agg(sum("..."))
report_quantity = df.groupBy("Category") \
                    .agg(sum("Quantity").alias("Total_Quantity")) \
                    .orderBy(col("Total_Quantity").desc())

report_quantity.show()
# Out:
# +---------+--------------+
# | Category|Total_Quantity|
# +---------+--------------+
# |Accessory|           125|
# |  Display|            66|
# | Computer|            47|
# |    Audio|            47|
# +---------+--------------+

# %% [markdown]
# ##**PHẦN 5: SQL TRONG SPARK (SPARK SQL)**
# **Khái niệm**: Nếu bạn quen dùng SQL, Spark cho phép bạn viết query trực tiếp.
#
# ###**5. Ví dụ minh họa**
# Tìm các sản phẩm có giá > 400 bằng câu lệnh SQL.

# %%
# Bước 1: Tạo một "View" tạm thời (giống như bảng ảo)
df.createOrReplaceTempView("SalesTable")

# Bước 2: Viết SQL
sql_result = spark.sql("SELECT Product, Price, City FROM SalesTable WHERE Price > 400")

sql_result.show()
# Out:
# +---------+-----+------+
# |  Product|Price|  City|
# +---------+-----+------+
# |   Laptop|  460|   HCM|
# |   Laptop|  470| Hanoi|
# |    Mouse|  470|Danang|
# |   Laptop|  430|   HCM|
# |  Monitor|  480|   HCM|
# | Keyboard|  470|   HCM|
# |    Mouse|  430|Danang|
# |Headphone|  440|Danang|
# | Keyboard|  420| Hanoi|
# | Keyboard|  470|Cantho|
# |  Monitor|  460|   HCM|
# |   Laptop|  420|Danang|
# |  Monitor|  470|Cantho|
# |  Monitor|  440| Hanoi|
# |  Monitor|  450|   HCM|
# |   Laptop|  410|Cantho|
# |  Monitor|  440|Cantho|
# | Keyboard|  410|Cantho|
# |   Laptop|  420|Cantho|
# |   Laptop|  470|Danang|
# +---------+-----+------+
# only showing top 20 rows

# %% [markdown]
# ###**Bài tập 5 (Sinh viên code tại đây)**
# **Yêu cầu**: Dùng spark.sql để tính trung bình cộng giá (AVG(Price)) của các sản phẩm bán tại 'HCM'.

# %%
# CODE CỦA BẠN Ở ĐÂY:
# Query mau: "SELECT AVG(...) as AvgPrice FROM SalesTable WHERE ..."
sql_result_avg = spark.sql("SELECT AVG(Price) as AvgPrice FROM SalesTable WHERE City = 'HCM'")
sql_result_avg.show()
# Out:
# +------------------+
# |          AvgPrice|
# +------------------+
# |323.44827586206895|
# +------------------+

# %% [markdown]
# ##**PHẦN KẾT: LƯU TRỮ DỮ LIỆU (PARQUET)**
# Sau khi xử lý xong, Data Engineer phải lưu dữ liệu lại.

# %%
# Lưu kết quả ra file Parquet (định dạng tối ưu cho Big Data)
output_path = "processed_sales_data"

# mode("overwrite"): Ghi đè nếu folder đã tồn tại
df.write.mode("overwrite").parquet(output_path)

print(f"✅ Đã lưu dữ liệu vào thư mục: {output_path}")

# Kiểm tra lại bằng cách đọc lên
spark.read.parquet(output_path).show(3)
# Out:
# ✅ Đã lưu dữ liệu vào thư mục: processed_sales_data
# +-------------+-------+---------+-----+--------+------+
# |TransactionID|Product| Category|Price|Quantity|  City|
# +-------------+-------+---------+-----+--------+------+
# |      TRX_001|  Mouse|Accessory|  350|       3|Danang|
# |      TRX_002|Monitor|  Display|  170|       3|Danang|
# |      TRX_003| Laptop| Computer|  130|       5| Hanoi|
# +-------------+-------+---------+-----+--------+------+
# only showing top 3 rows
